# %%
l=[1,2,3,4,5]
a=[x**3 for x in l]
a
# Out:
# [1, 8, 27, 64, 125]

# %%
a=1+2
a
# Out:
# 3

# %%
l[-3:]
print(l[0])
l.insert(1,33)
l
# Out:
# 1
# [1, 33, 2, 3, 4, 5]

# %% [markdown]
# ##remove
# -one
# -two

# %% [markdown]
# -one

# %%
l.remove(33)
l
# Out:
# [1, 2, 3, 4, 5]

# %%
a=l.pop(2)
print(a)
# Out:
# 4

# %%
print(l)
# Out:
# [1, 2, 5]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [5, 2, 1]

# %%
l.reverse()
l
# Out:
# [1, 2, 5]

# %%
tup=(1,2,3,4,4)
tup[1]
# Out:
# 2

# %%
lst=[]
for i in range(6):
    num=int(input(f"Enter number{i+1}: "))
    lst.append(num)

print(lst)
